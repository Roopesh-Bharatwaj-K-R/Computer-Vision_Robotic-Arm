# %% [markdown]
# <a href="https://colab.research.google.com/github/Roopesh-Bharatwaj-K-R/Lego-Mind-Storm-Robotic-Arm/blob/Master/test_ball_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# save file
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import os
path = "/content/gdrive/MyDrive/yolov5" # /content is pretty much the root. you can choose other path in your colab workspace
os.chdir(path)

# %%
import torch
model = torch.hub.load('ultralytics/yolov5','custom', path ='/content/gdrive/MyDrive/yolov5/runs/train/exp/weights/firstbest.pt', force_reload = True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# ...
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-4-2 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7023610 parameters, 0 gradients
# Adding AutoShape...

# %%
import os
img = '/content/gdrive/MyDrive/yolov5/Ball-Detection-2/train/images/IMG_20220326_160144_jpg.rf.0c21f4d9423f7013e6d089aa074d87dd.jpg'

# %%
from torchvision import transforms
#img1= np.ndarray(img)
import PIL
from PIL import Image
image= PIL.Image.open(img).convert('RGB')
#image= Image.open(img)
convert_tensor = transforms.ToTensor()
convert_tensor(image)
print(image.size)
# Out:
# (416, 416)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
print(img)
# Out:
# /content/gdrive/MyDrive/yolov5/Ball-Detection-2/train/images/IMG_20220326_160144_jpg.rf.0c21f4d9423f7013e6d089aa074d87dd.jpg

# %%
#from google.colab import files
#image= files.upload()

# %%
results= model(image)
results.print()
print(results.pandas().xyxy[0])
plt.imshow(np.squeeze(results.render()))
# Out:
# image 1/1: 416x416 1 Rugby
# Speed: 37.7ms pre-process, 593.7ms inference, 17.1ms NMS per image at shape (1, 3, 640, 640)
#         xmin      ymin        xmax        ymax  confidence  class   name
# 0  60.055801  66.99144  294.001984  310.551849    0.624924      2  Rugby

# %%
print(results)
#[print(re.shape)for re in results]

# %%
out = model(image)
print(out.size)
#[print(o.shape) for o in out]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-26f50154d992> in <module>()
#       1 out = model(image)
# ----> 2 print(out.size)
#       3 #[print(o.shape) for o in out]
#
# AttributeError: 'Detections' object has no attribute 'size'
